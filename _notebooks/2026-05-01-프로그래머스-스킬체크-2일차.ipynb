# %% [markdown]
# # 프로그래머스 스킬체크 2일차
#
# > "아무튼 프로 코딩러임"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: 한재수
# - categories: [Algorithm]

# %% [markdown]
# `-` 오늘은 프로 코딩러가 되보도록 하자

# %% [markdown]
# ## 프로 코딩러 (레벨 4)

# %% [markdown]
# `-` 1트(불합격): 분할 정복 문제가 나왔는데 못풀었다
#
# `-` 2트(불합격): 손절한 문제가 나왔다
#
# `-` 3트(불합격): 이분 탐색에 닦였다
#
# `-` 4트(불합격): 손절한 문제가 또 나왔다
#
# `-` 5트(합격): DP와 그래프 문제가 나왔고 어렵지 않게 풀었다
#
# `-` 어제 오늘 도합 10트만에 합격했다...

# %% [markdown]
# ![](my_icons/skillcheck-lv4-1.png) ![](my_icons/skillcheck-lv4-2.png)

# %% [markdown]
# ## 현재까지 취득한 뱃지

# %% [markdown]
# ![](my_icons/2026-05-01-skillcheck-badge.png)

# %% [markdown]
# `-` 내일은 알고리즘 마스터가 되보도록 하자
